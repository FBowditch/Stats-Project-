# %%
import config
import pandas as pd
from sodapy import Socrata
import mysql.connector
import alc_connect as alc

# %% [markdown]
# ## Pulling All Arrest Data From Jan 1st 2019 - Present in Brooklyn, NY

# %%
client = Socrata(config.url, config.api_key)

results = client.get("uip8-fykc", arrest_boro="K", limit=50000)

df = pd.DataFrame.from_records(results)

# %%
df.head()
# Out:
#   arrest_key              arrest_date pd_cd                         pd_desc  \
# 0  203066328  2019-09-30T00:00:00.000   779  PUBLIC ADMINISTRATION,UNCLASSI
# 1  203068778  2019-09-30T00:00:00.000   922  TRAFFIC,UNCLASSIFIED MISDEMEAN
# 2  203074208  2019-09-30T00:00:00.000   779  PUBLIC ADMINISTRATION,UNCLASSI
# 3  203074210  2019-09-30T00:00:00.000   101                       ASSAULT 3
# 4  203075937  2019-09-30T00:00:00.000   179        AGGRAVATED SEXUAL ASBUSE
#
#    ky_cd                     ofns_desc    law_code law_cat_cd arrest_boro  \
# 0  126.0       MISCELLANEOUS PENAL LAW  PL 215510B          F           K
# 1  348.0      VEHICLE AND TRAFFIC LAWS  VTL0511001          M           K
# 2  126.0       MISCELLANEOUS PENAL LAW  PL 215510D          F           K
# 3  344.0  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           K
# 4  116.0                    SEX CRIMES  PL 130651A          F           K
#
#   arrest_precinct jurisdiction_code age_group perp_sex perp_race x_coord_cd  \
# 0              63                 0     45-64        M     BLACK    1000521
# 1              70                 0     45-64        M     BLACK     995070
# 2              67                 0     25-44        M     BLACK    1003705
# 3              84                 0     18-24        F     BLACK     986229
# 4              73                 0     18-24        M     BLACK    1008276
#
#   y_coord_cd            latitude           longitude
# 0     168264   40.62851560000007  -73.94138369799998
# 1     176121   40.65008972100002  -73.96100881399997
# 2     176766   40.65184534600007  -73.92988853999998
# 3     193497  40.697789330000035  -73.99286451299997
# 4     183623  40.670655072000045  -73.91339091999998

# %% [markdown]
# ## Droping Irrelevant Columns

# %%
df.drop(['pd_cd', 'ky_cd', 'x_coord_cd','y_coord_cd','jurisdiction_code', 'law_code', 'arrest_key','arrest_precinct','arrest_boro', 'pd_desc'], axis = 1, inplace = True)

# %% [markdown]
# ## Changing Object Type (Latitude, Longitude, Date)

# %%
df["latitude"] = df.latitude.astype(float)

# %%
df['longitude'] = df.longitude.astype(float)

# %%
df['arrest_date'] = pd.to_datetime(df['arrest_date'])

# %%
df.head()
# Out:
#   arrest_date                     ofns_desc law_cat_cd age_group perp_sex  \
# 0  2019-09-30       MISCELLANEOUS PENAL LAW          F     45-64        M
# 1  2019-09-30      VEHICLE AND TRAFFIC LAWS          M     45-64        M
# 2  2019-09-30       MISCELLANEOUS PENAL LAW          F     25-44        M
# 3  2019-09-30  ASSAULT 3 & RELATED OFFENSES          M     18-24        F
# 4  2019-09-30                    SEX CRIMES          F     18-24        M
#
#   perp_race   latitude  longitude
# 0     BLACK  40.628516 -73.941384
# 1     BLACK  40.650090 -73.961009
# 2     BLACK  40.651845 -73.929889
# 3     BLACK  40.697789 -73.992865
# 4     BLACK  40.670655 -73.913391

# %% [markdown]
# ## Renaming Columns

# %%
df.rename(columns={'arrest_date': 'Date', 'ofns_desc':'Crime_Description', 'law_cat_cd':'Offense_Level', 'age_group':'Age_Group','perp_sex':'Sex','perp_race':'Race','latitude':'Latitude','longitude':'Longitude'}, inplace=True)

# %%
df
# Out:
#             Date               Crime_Description Offense_Level Age_Group Sex  \
# 0     2019-09-30         MISCELLANEOUS PENAL LAW             F     45-64   M
# 1     2019-09-30        VEHICLE AND TRAFFIC LAWS             M     45-64   M
# 2     2019-09-30         MISCELLANEOUS PENAL LAW             F     25-44   M
# 3     2019-09-30    ASSAULT 3 & RELATED OFFENSES             M     18-24   F
# 4     2019-09-30                      SEX CRIMES             F     18-24   M
# ...          ...                             ...           ...       ...  ..
# 45668 2019-01-01                   PETIT LARCENY             M     25-44   M
# 45669 2019-01-01               DANGEROUS WEAPONS             F     25-44   M
# 45670 2019-01-01               DANGEROUS WEAPONS             F     25-44   M
# 45671 2019-01-01                         FORGERY             F     45-64   M
# 45672 2019-01-01  INTOXICATED & IMPAIRED DRIVING             M     45-64   M
#
#         Race   Latitude  Longitude
# 0      BLACK  40.628516 -73.941384
# 1      BLACK  40.650090 -73.961009
# 2      BLACK  40.651845 -73.929889
# 3      BLACK  40.697789 -73.992865
# 4      BLACK  40.670655 -73.913391
# ...      ...        ...        ...
# 45668  WHITE  40.609900 -73.922373
# 45669  BLACK  40.664828 -73.888304
# 45670  BLACK  40.676052 -73.934611
# 45671  BLACK  40.658586 -73.890624
# 45672  BLACK  40.673246 -73.964990
#
# [45673 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45673 entries, 0 to 45672
# Data columns (total 9 columns):
# Date                 45673 non-null datetime64[ns]
# Crime_Description    45673 non-null object
# Offense_Level        45673 non-null object
# Age_Group            45673 non-null object
# Sex                  45673 non-null object
# Race                 45673 non-null object
# Latitude             45673 non-null float64
# Longitude            45673 non-null float64
# average              45673 non-null float64
# dtypes: datetime64[ns](1), float64(3), object(5)
# memory usage: 3.1+ MB

# %% [markdown]
# ## Droping Rows with Null Values (Col. Offense_Level & Crime_Description)

# %%
df = df.dropna(how='any',axis=0)

# %%
df.count()
# Out:
# Date                 45673
# Crime_Description    45673
# Offense_Level        45673
# Age_Group            45673
# Sex                  45673
# Race                 45673
# Latitude             45673
# Longitude            45673
# dtype: int64

# %% [markdown]
# ## Sending to SQL Database

# %%
df.to_sql('brooklyn_arrest', alc.db, if_exists = 'replace', index = False)

# %% [markdown]
# ## Creating New DataFrames

# %%
by_crime = df.groupby(['Date','Crime_Description']).count()

# %%
by_crime
# Out:
#            Date               Crime_Description  Count
# 0    2019-01-01    ASSAULT 3 & RELATED OFFENSES     22
# 1    2019-01-01  CRIMINAL MISCHIEF & RELATED OF      5
# 2    2019-01-01               CRIMINAL TRESPASS      2
# 3    2019-01-01                 DANGEROUS DRUGS     13
# 4    2019-01-01               DANGEROUS WEAPONS      9
# ...         ...                             ...    ...
# 7449 2019-09-30                            RAPE      1
# 7450 2019-09-30                         ROBBERY     14
# 7451 2019-09-30                      SEX CRIMES      4
# 7452 2019-09-30   UNAUTHORIZED USE OF A VEHICLE      2
# 7453 2019-09-30        VEHICLE AND TRAFFIC LAWS     10
#
# [7454 rows x 3 columns]

# %%
by_crime.drop(['Age_Group', 'Sex', 'Race','Latitude','Longitude'], axis = 1, inplace = True)

# %%
by_crime.rename(columns={'Offense_Level': 'Count'}, inplace=True)

# %%
by_crime.reset_index(inplace = True)

# %%
by_crime.set_index('Date')
# Out:
#                          Crime_Description  Count
# Date
# 2019-01-01    ASSAULT 3 & RELATED OFFENSES     22
# 2019-01-01  CRIMINAL MISCHIEF & RELATED OF      5
# 2019-01-01               CRIMINAL TRESPASS      2
# 2019-01-01                 DANGEROUS DRUGS     13
# 2019-01-01               DANGEROUS WEAPONS      9
# ...                                    ...    ...
# 2019-09-30                            RAPE      1
# 2019-09-30                         ROBBERY     14
# 2019-09-30                      SEX CRIMES      4
# 2019-09-30   UNAUTHORIZED USE OF A VEHICLE      2
# 2019-09-30        VEHICLE AND TRAFFIC LAWS     10
#
# [7454 rows x 2 columns]

# %%
by_crime
# Out:
#            Date               Crime_Description  Count
# 0    2019-01-01    ASSAULT 3 & RELATED OFFENSES     22
# 1    2019-01-01  CRIMINAL MISCHIEF & RELATED OF      5
# 2    2019-01-01               CRIMINAL TRESPASS      2
# 3    2019-01-01                 DANGEROUS DRUGS     13
# 4    2019-01-01               DANGEROUS WEAPONS      9
# ...         ...                             ...    ...
# 7449 2019-09-30                            RAPE      1
# 7450 2019-09-30                         ROBBERY     14
# 7451 2019-09-30                      SEX CRIMES      4
# 7452 2019-09-30   UNAUTHORIZED USE OF A VEHICLE      2
# 7453 2019-09-30        VEHICLE AND TRAFFIC LAWS     10
#
# [7454 rows x 3 columns]

# %%
df['Average_Temp'] = df[['Latitude', 'Longitude']].apply(lambda x: (x['Latitude'] + x['Longitude'])/2, axis = 1)

# %%
df.drop(['average'], axis = 1, inplace = True)

# %%
df.groupby(['Date', 'Sex']).count()
# Out:
#                 Crime_Description  Offense_Level  Age_Group  Race  Latitude  \
# Date       Sex
# 2019-01-01 F                   18             18         18    18        18
#            M                  114            114        114   114       114
# 2019-01-02 F                   41             41         41    41        41
#            M                  137            137        137   137       137
# 2019-01-03 F                   27             27         27    27        27
# ...                           ...            ...        ...   ...       ...
# 2019-09-28 M                   90             90         90    90        90
# 2019-09-29 F                   26             26         26    26        26
#            M                   77             77         77    77        77
# 2019-09-30 F                   15             15         15    15        15
#            M                  103            103        103   103       103
#
#                 Longitude
# Date       Sex
# 2019-01-01 F           18
#            M          114
# 2019-01-02 F           41
#            M          137
# 2019-01-03 F           27
# ...                   ...
# 2019-09-28 M           90
# 2019-09-29 F           26
#            M           77
# 2019-09-30 F           15
#            M          103
#
# [546 rows x 6 columns]

# %%
all_data = pd.read_sql_query('Select * FROM brooklyn_weather JOIN brooklyn_arrest ON brooklyn_arrest.Date = brooklyn_weather.Date', alc.db)

# %% [markdown]
# dropping duplicate column ('Date')

# %%
cols = []
count = 1
for column in all_data.columns:
    if column == 'Date':
        cols.append(f'Date_{count}')
        count+=1
        continue
    cols.append(column)
all_data.columns = cols

# %%
all_data.drop(['Date_2'], axis = 1, inplace = True)

# %%
all_data.rename(columns ={'Date_1':'Date'}, inplace = True)

# %%
all_data.to_csv("output.csv")

# %%
dw = all_data.groupby(['Date', 'Forecast']).count()

# %% [markdown]
# dw - all_data with date and weather as multi_index

# %%
dw
# Out:
#                               Moon Phase  Wind Speed  Average_Temp  \
# Date       Forecast
# 2019-01-01 rain                      132         132           132
# 2019-01-02 partly-cloudy-day         178         178           178
# 2019-01-03 partly-cloudy-day         226         226           226
# 2019-01-04 clear-day                 205         205           205
# 2019-01-05 rain                      175         175           175
# ...                                  ...         ...           ...
# 2019-09-26 rain                      184         184           184
# 2019-09-27 clear-day                 168         168           168
# 2019-09-28 partly-cloudy-day         104         104           104
# 2019-09-29 clear-day                 103         103           103
# 2019-09-30 partly-cloudy-day         118         118           118
#
#                               Crime_Description  Offense_Level  Age_Group  \
# Date       Forecast
# 2019-01-01 rain                             132            132        132
# 2019-01-02 partly-cloudy-day                178            178        178
# 2019-01-03 partly-cloudy-day                226            226        226
# 2019-01-04 clear-day                        205            205        205
# 2019-01-05 rain                             175            175        175
# ...                                         ...            ...        ...
# 2019-09-26 rain                             184            184        184
# 2019-09-27 clear-day                        168            168        168
# 2019-09-28 partly-cloudy-day                104            104        104
# 2019-09-29 clear-day                        103            103        103
# 2019-09-30 partly-cloudy-day                118            118        118
#
#                               Sex  Race  Latitude  Longitude
# Date       Forecast
# 2019-01-01 rain               132   132       132        132
# 2019-01-02 partly-cloudy-day  178   178       178        178
# 2019-01-03 partly-cloudy-day  226   226       226        226
# 2019-01-04 clear-day          205   205       205        205
# 2019-01-05 rain               175   175       175        175
# ...                           ...   ...       ...        ...
# 2019-09-26 rain               184   184       184        184
# 2019-09-27 clear-day          168   168       168        168
# 2019-09-28 partly-cloudy-day  104   104       104        104
# 2019-09-29 clear-day          103   103       103        103
# 2019-09-30 partly-cloudy-day  118   118       118        118
#
# [271 rows x 10 columns]
